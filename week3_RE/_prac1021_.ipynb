# %%
import re

text = '''
Hello world! This is a test message.
My email is example_123@test.com, and my backup is hello.world2025@gmail.com.
I have 2 cats, 1 dog, and 0 patience.
Visit https://www.python.org or http://example.net for more info.
The password is "abc_123!" — please don't share it.
'''
